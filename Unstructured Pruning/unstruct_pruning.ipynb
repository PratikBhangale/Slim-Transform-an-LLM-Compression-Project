# %%
import torch
import torch.nn.utils.prune as prune
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

token = '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'

# Load the LLaMA model
model_name = "meta-llama/Llama-3.2-1B-Instruct" 
model = AutoModelForCausalLM.from_pretrained(model_name, token=token)
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.1-8B-Instruct")


# Define a function to apply unstructured pruning to specific layers
def apply_unstructured_pruning(model, pruning_amount=0.3):
    """
    Apply unstructured pruning to linear layers of the model.

    Args:
        model: The PyTorch model to prune.
        pruning_amount: The proportion of weights to prune (0 to 1).
    """
    for name, module in model.named_modules():
        if isinstance(module, torch.nn.Linear):
            print(f"Applying pruning to layer: {name}")
            prune.random_unstructured(module, name='weight', amount=pruning_amount)

# %%
# Apply pruning to the model
pruning_amount = 0.2 
apply_unstructured_pruning(model, pruning_amount)

# Check sparsity of a layer
def check_sparsity(module):
    """Check the sparsity of a given module."""
    if hasattr(module, 'weight'):
        weight = module.weight
        sparsity = 100.0 * float(torch.sum(weight == 0)) / weight.numel()
        print(f"Sparsity: {sparsity:.2f}%")

# Example: Check sparsity of the first linear layer
for name, module in model.named_modules():
    if isinstance(module, torch.nn.Linear):
        print(f"Checking sparsity of layer: {name}")
        check_sparsity(module)
        break
# Out:
# Applying pruning to layer: model.layers.0.self_attn.q_proj
# Applying pruning to layer: model.layers.0.self_attn.k_proj
# Applying pruning to layer: model.layers.0.self_attn.v_proj
# Applying pruning to layer: model.layers.0.self_attn.o_proj
# Applying pruning to layer: model.layers.0.mlp.gate_proj
# Applying pruning to layer: model.layers.0.mlp.up_proj
# Applying pruning to layer: model.layers.0.mlp.down_proj
# Applying pruning to layer: model.layers.1.self_attn.q_proj
# Applying pruning to layer: model.layers.1.self_attn.k_proj
# Applying pruning to layer: model.layers.1.self_attn.v_proj
# Applying pruning to layer: model.layers.1.self_attn.o_proj
# Applying pruning to layer: model.layers.1.mlp.gate_proj
# Applying pruning to layer: model.layers.1.mlp.up_proj
# Applying pruning to layer: model.layers.1.mlp.down_proj
# Applying pruning to layer: model.layers.2.self_attn.q_proj
# Applying pruning to layer: model.layers.2.self_attn.k_proj
# Applying pruning to layer: model.layers.2.self_attn.v_proj
# Applying pruning to layer: model.layers.2.self_attn.o_proj
# Applying pruning to layer: model.layers.2.mlp.gate_proj
# Applying pruning to layer: model.layers.2.mlp.up_proj
# Applying pruning to layer: model.layers.2.mlp.down_proj
# Applying pruning to layer: model.layers.3.self_attn.q_proj
# Applying pruning to layer: model.layers.3.self_attn.k_proj
# Applying pruning to layer: model.layers.3.self_attn.v_proj
# Applying pruning to layer: model.layers.3.self_attn.o_proj
# Applying pruning to layer: model.layers.3.mlp.gate_proj
# Applying pruning to layer: model.layers.3.mlp.up_proj
# Applying pruning to layer: model.layers.3.mlp.down_proj
# Applying pruning to layer: model.layers.4.self_attn.q_proj
# Applying pruning to layer: model.layers.4.self_attn.k_proj
# Applying pruning to layer: model.layers.4.self_attn.v_proj
# Applying pruning to layer: model.layers.4.self_attn.o_proj
# Applying pruning to layer: model.layers.4.mlp.gate_proj
# Applying pruning to layer: model.layers.4.mlp.up_proj
# Applying pruning to layer: model.layers.4.mlp.down_proj
# Applying pruning to layer: model.layers.5.self_attn.q_proj
# Applying pruning to layer: model.layers.5.self_attn.k_proj
# Applying pruning to layer: model.layers.5.self_attn.v_proj
# Applying pruning to layer: model.layers.5.self_attn.o_proj
# Applying pruning to layer: model.layers.5.mlp.gate_proj
# Applying pruning to layer: model.layers.5.mlp.up_proj
# Applying pruning to layer: model.layers.5.mlp.down_proj
# Applying pruning to layer: model.layers.6.self_attn.q_proj
# Applying pruning to layer: model.layers.6.self_attn.k_proj
# Applying pruning to layer: model.layers.6.self_attn.v_proj
# Applying pruning to layer: model.layers.6.self_attn.o_proj
# Applying pruning to layer: model.layers.6.mlp.gate_proj
# Applying pruning to layer: model.layers.6.mlp.up_proj
# Applying pruning to layer: model.layers.6.mlp.down_proj
# Applying pruning to layer: model.layers.7.self_attn.q_proj
# Applying pruning to layer: model.layers.7.self_attn.k_proj
# Applying pruning to layer: model.layers.7.self_attn.v_proj
# Applying pruning to layer: model.layers.7.self_attn.o_proj
# Applying pruning to layer: model.layers.7.mlp.gate_proj
# Applying pruning to layer: model.layers.7.mlp.up_proj
# Applying pruning to layer: model.layers.7.mlp.down_proj
# Applying pruning to layer: model.layers.8.self_attn.q_proj
# Applying pruning to layer: model.layers.8.self_attn.k_proj
# Applying pruning to layer: model.layers.8.self_attn.v_proj
# Applying pruning to layer: model.layers.8.self_attn.o_proj
# Applying pruning to layer: model.layers.8.mlp.gate_proj
# Applying pruning to layer: model.layers.8.mlp.up_proj
# Applying pruning to layer: model.layers.8.mlp.down_proj
# Applying pruning to layer: model.layers.9.self_attn.q_proj
# Applying pruning to layer: model.layers.9.self_attn.k_proj
# Applying pruning to layer: model.layers.9.self_attn.v_proj
# Applying pruning to layer: model.layers.9.self_attn.o_proj
# Applying pruning to layer: model.layers.9.mlp.gate_proj
# Applying pruning to layer: model.layers.9.mlp.up_proj
# Applying pruning to layer: model.layers.9.mlp.down_proj
# Applying pruning to layer: model.layers.10.self_attn.q_proj
# Applying pruning to layer: model.layers.10.self_attn.k_proj
# Applying pruning to layer: model.layers.10.self_attn.v_proj
# Applying pruning to layer: model.layers.10.self_attn.o_proj
# Applying pruning to layer: model.layers.10.mlp.gate_proj
# Applying pruning to layer: model.layers.10.mlp.up_proj
# Applying pruning to layer: model.layers.10.mlp.down_proj
# Applying pruning to layer: model.layers.11.self_attn.q_proj
# Applying pruning to layer: model.layers.11.self_attn.k_proj
# Applying pruning to layer: model.layers.11.self_attn.v_proj
# Applying pruning to layer: model.layers.11.self_attn.o_proj
# Applying pruning to layer: model.layers.11.mlp.gate_proj
# Applying pruning to layer: model.layers.11.mlp.up_proj
# Applying pruning to layer: model.layers.11.mlp.down_proj
# Applying pruning to layer: model.layers.12.self_attn.q_proj
# Applying pruning to layer: model.layers.12.self_attn.k_proj
# Applying pruning to layer: model.layers.12.self_attn.v_proj
# Applying pruning to layer: model.layers.12.self_attn.o_proj
# Applying pruning to layer: model.layers.12.mlp.gate_proj
# Applying pruning to layer: model.layers.12.mlp.up_proj
# Applying pruning to layer: model.layers.12.mlp.down_proj
# Applying pruning to layer: model.layers.13.self_attn.q_proj
# Applying pruning to layer: model.layers.13.self_attn.k_proj
# Applying pruning to layer: model.layers.13.self_attn.v_proj
# Applying pruning to layer: model.layers.13.self_attn.o_proj
# Applying pruning to layer: model.layers.13.mlp.gate_proj
# Applying pruning to layer: model.layers.13.mlp.up_proj
# Applying pruning to layer: model.layers.13.mlp.down_proj
# Applying pruning to layer: model.layers.14.self_attn.q_proj
# Applying pruning to layer: model.layers.14.self_attn.k_proj
# Applying pruning to layer: model.layers.14.self_attn.v_proj
# Applying pruning to layer: model.layers.14.self_attn.o_proj
# Applying pruning to layer: model.layers.14.mlp.gate_proj
# Applying pruning to layer: model.layers.14.mlp.up_proj
# Applying pruning to layer: model.layers.14.mlp.down_proj
# Applying pruning to layer: model.layers.15.self_attn.q_proj
# Applying pruning to layer: model.layers.15.self_attn.k_proj
# Applying pruning to layer: model.layers.15.self_attn.v_proj
# Applying pruning to layer: model.layers.15.self_attn.o_proj
# Applying pruning to layer: model.layers.15.mlp.gate_proj
# Applying pruning to layer: model.layers.15.mlp.up_proj
# Applying pruning to layer: model.layers.15.mlp.down_proj
# Applying pruning to layer: lm_head
# Checking sparsity of layer: model.layers.0.self_attn.q_proj
# Sparsity: 20.00%

# %%
# Save the pruned model
model.save_pretrained("./unstructured_prune_model")
tokenizer.save_pretrained("./unstructured_prune_model")
# Out:
# ('./unstructured_prune_model\\tokenizer_config.json',
#  './unstructured_prune_model\\special_tokens_map.json',
#  './unstructured_prune_model\\tokenizer.json')
