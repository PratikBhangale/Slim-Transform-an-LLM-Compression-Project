# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from torch.nn.utils import prune
from torch.quantization import quantize_dynamic

token = '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'

# Load model and tokenizer from Hugging Face
model_name = "meta-llama/Llama-3.2-1B-Instruct"
model = AutoModelForCausalLM.from_pretrained(model_name, token=token)
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.1-8B-Instruct")

# Ensure model is in training mode for pruning
model.train()

# Define pruning on Linear layers
def apply_pruning(model, amount=0.3):
    for name, module in model.named_modules():
        if isinstance(module, torch.nn.Linear):
            prune.l1_unstructured(module, name='weight', amount=amount)
            print(f"Pruned {name}: {amount*100}% of weights")

# %%
# Apply pruning to the model
pruning_amount = 0.3  # Example: prune 50% of weights
apply_pruning(model, pruning_amount)

# Remove pruning masks
for name, module in model.named_modules():
    if isinstance(module, torch.nn.Linear):
        prune.remove(module, 'weight')

# Convert model to dynamic quantization
quantized_model = quantize_dynamic(
    model,
    {torch.nn.Linear}, 
    dtype=torch.qint8
)
# Out:
# Pruned model.layers.0.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.0.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.0.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.0.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.0.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.0.mlp.up_proj: 30.0% of weights
# Pruned model.layers.0.mlp.down_proj: 30.0% of weights
# Pruned model.layers.1.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.1.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.1.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.1.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.1.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.1.mlp.up_proj: 30.0% of weights
# Pruned model.layers.1.mlp.down_proj: 30.0% of weights
# Pruned model.layers.2.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.2.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.2.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.2.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.2.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.2.mlp.up_proj: 30.0% of weights
# Pruned model.layers.2.mlp.down_proj: 30.0% of weights
# Pruned model.layers.3.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.3.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.3.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.3.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.3.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.3.mlp.up_proj: 30.0% of weights
# Pruned model.layers.3.mlp.down_proj: 30.0% of weights
# Pruned model.layers.4.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.4.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.4.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.4.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.4.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.4.mlp.up_proj: 30.0% of weights
# Pruned model.layers.4.mlp.down_proj: 30.0% of weights
# Pruned model.layers.5.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.5.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.5.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.5.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.5.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.5.mlp.up_proj: 30.0% of weights
# Pruned model.layers.5.mlp.down_proj: 30.0% of weights
# Pruned model.layers.6.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.6.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.6.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.6.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.6.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.6.mlp.up_proj: 30.0% of weights
# Pruned model.layers.6.mlp.down_proj: 30.0% of weights
# Pruned model.layers.7.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.7.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.7.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.7.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.7.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.7.mlp.up_proj: 30.0% of weights
# Pruned model.layers.7.mlp.down_proj: 30.0% of weights
# Pruned model.layers.8.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.8.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.8.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.8.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.8.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.8.mlp.up_proj: 30.0% of weights
# Pruned model.layers.8.mlp.down_proj: 30.0% of weights
# Pruned model.layers.9.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.9.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.9.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.9.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.9.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.9.mlp.up_proj: 30.0% of weights
# Pruned model.layers.9.mlp.down_proj: 30.0% of weights
# Pruned model.layers.10.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.10.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.10.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.10.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.10.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.10.mlp.up_proj: 30.0% of weights
# Pruned model.layers.10.mlp.down_proj: 30.0% of weights
# Pruned model.layers.11.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.11.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.11.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.11.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.11.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.11.mlp.up_proj: 30.0% of weights
# Pruned model.layers.11.mlp.down_proj: 30.0% of weights
# Pruned model.layers.12.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.12.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.12.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.12.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.12.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.12.mlp.up_proj: 30.0% of weights
# Pruned model.layers.12.mlp.down_proj: 30.0% of weights
# Pruned model.layers.13.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.13.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.13.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.13.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.13.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.13.mlp.up_proj: 30.0% of weights
# Pruned model.layers.13.mlp.down_proj: 30.0% of weights
# Pruned model.layers.14.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.14.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.14.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.14.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.14.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.14.mlp.up_proj: 30.0% of weights
# Pruned model.layers.14.mlp.down_proj: 30.0% of weights
# Pruned model.layers.15.self_attn.q_proj: 30.0% of weights
# Pruned model.layers.15.self_attn.k_proj: 30.0% of weights
# Pruned model.layers.15.self_attn.v_proj: 30.0% of weights
# Pruned model.layers.15.self_attn.o_proj: 30.0% of weights
# Pruned model.layers.15.mlp.gate_proj: 30.0% of weights
# Pruned model.layers.15.mlp.up_proj: 30.0% of weights
# Pruned model.layers.15.mlp.down_proj: 30.0% of weights
# Pruned lm_head: 30.0% of weights

# %%
# Save the state dictionary 
save_path = "llama-quantized-pruned"
torch.save(quantized_model.state_dict(), f"{save_path}/pytorch_model.bin")

# Save the tokenizer
tokenizer.save_pretrained(save_path)

print("Quantization and pruning complete. Model and tokenizer saved.")
# Out:
# Quantization and pruning complete. Model and tokenizer saved.
